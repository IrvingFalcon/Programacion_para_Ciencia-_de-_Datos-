# %% [markdown]
# <a href="https://colab.research.google.com/github/IrvingFalcon/Programacion_para_Ciencia-_de-_Datos-/blob/main/lista2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lista=[]
for i in range(0,10,2):
    lista.append(i)
print (lista)

for i in range (10,0,-2):
  print (i)
# Out:
# [0, 2, 4, 6, 8]
# 10
# 8
# 6
# 4
# 2
