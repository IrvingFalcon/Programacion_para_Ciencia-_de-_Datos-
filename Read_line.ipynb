# %% [markdown]
# <a href="https://colab.research.google.com/github/IrvingFalcon/Programacion_para_Ciencia-_de-_Datos-/blob/main/Read_line.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 total_words = 0

with open("/content/drive/MyDrive/archivo.txt", encoding='utf8') as f:
  for line in f:#lee el texto linea por linea
   print(line.split())
  for palabras in line.split():#lee cada palabra del texto
    total_words+=1

    print(total_words)
# Out:
# ['dfecfrfrefrrftrtgrgt']
# ['tergtrgrtrgt']
# []
# ['rgtgtrrtrtg']
# 1
