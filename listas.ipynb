# %% [markdown]
# <a href="https://colab.research.google.com/github/IrvingFalcon/Programacion_para_Ciencia-_de-_Datos-/blob/main/listas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lista=[] #generar una lista vacia
lista.append(4.0) #agrego un elemento flotante a la lista
lista.append('a') #agrego una cadena a la lista
print (type(lista))
print (type(lista[0]))
print (type(lista[1]))
print (len(lista)) #longitud de la lista
lista.append('2.0')
lista[2]=float(lista[2])
print (lista)
lista.pop(1) #elimina el elemento 1 de la lista
print (lista)
lista.insert(1,'6.2') #introduce un elemento en la posicion 1
print (lista)
# The line below was causing lista to be cleared prematurely.
# lista=[]
lista2 = [] # Inicializar lista2
lista2.append(lista)
lista2.append('hola')
print (lista2)
print (lista2[0][1])
lista2[0][1]=2+2j
print (lista2)
lista[1]+=1 # Corrected from lista[0][1]+=1 to modify the second element of lista
print (lista2)
# Out:
# <class 'list'>
# <class 'float'>
# <class 'str'>
# 2
# [4.0, 'a', 2.0]
# [4.0, 2.0]
# [4.0, '6.2', 2.0]
# [[4.0, '6.2', 2.0], 'hola']
# 6.2
# [[4.0, (2+2j), 2.0], 'hola']
# [[4.0, (3+2j), 2.0], 'hola']

# %%
lista=[]
for i in range(0,10,2):
    lista.append(i)
print (lista)

for i in range (10,0,-2):
  print (i)
# Out:
# [0, 2, 4, 6, 8]
# 10
# 8
# 6
# 4
# 2
