# %% [markdown]
# <a href="https://colab.research.google.com/github/IrvingFalcon/Programacion_para_Ciencia-_de-_Datos-/blob/main/Expresiones_Regulares.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re #operaciones regulares

texto = "Expresiones regulares son utiles."
patron = '[aeiouAEIOU]'
resultado = re.sub(patron, "*", texto)#Reemplaza todas las vocales
print(resultado)
# Out:
# *xpr*s**n*s r*g*l*r*s s*n *t*l*s.
