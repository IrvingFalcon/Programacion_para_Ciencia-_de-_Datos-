# %% [markdown]
# <a href="https://colab.research.google.com/github/IrvingFalcon/Programacion_para_Ciencia-_de-_Datos-/blob/main/arregos2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt #libreria para graficar

x=np.ones((3,3)) #figura de 3cm x 3cm
f,c=np.shape(x)
print (f,c) #obtiene la dimension de la matriz

z=np.random.rand(4,4)
plt.imshow(z,cmap='gray')
plt.show()
# Out:
# 3 3
