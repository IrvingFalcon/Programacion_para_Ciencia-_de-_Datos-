# %% [markdown]
# <a href="https://colab.research.google.com/github/IrvingFalcon/Programacion_para_Ciencia-_de-_Datos-/blob/main/cadenas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cad='la inteligencia artificial es usada en ciencia de datos'
print (cad.split('e')) #devuelve una lista de cadenas utilizando el
                        #espacio como separador
# Out:
# ['la int', 'lig', 'ncia artificial ', 's usada ', 'n ci', 'ncia d', ' datos']
